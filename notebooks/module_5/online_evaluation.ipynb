# %% [markdown]
# # Online Evaluations

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
# Out:
# True

# %% [markdown]
# ### Running your Application

# %% [markdown]
# Let's run our application once, so we can see our new online evaluator run!

# %%
from app import langsmith_rag

question = "How do I set up tracing to LangSmith with @traceable?"
langsmith_rag(question)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# "To set up tracing to LangSmith with the @traceable decorator, first, ensure the LANGSMITH_TRACING environment variable is set to 'true' and set the LANGSMITH_API_KEY with your API key. Then, simply decorate the functions you want to trace using @traceable. Remember to use the await keyword when calling wrapped synchronous functions to ensure traces are logged correctly."
