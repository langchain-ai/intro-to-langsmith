# %% [markdown]
# # Filtering

# %% [markdown]
# ### Setup

# %%
# You can set them inline
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../.env", override=True)
# Out:
# True

# %% [markdown]
# ### Using filters in the SDK

# %% [markdown]
# Using the `list_runs` method in the SDK or `/runs/query` endpoint in the API, you can filter runs to analyze and export.

# %% [markdown]
# Let's paste in the raw query we copied from the UI

# %%
raw_query = """eq(name, "call_openai")"""

# %%
from langsmith import Client
from datetime import datetime, timedelta

client = Client()
runs = client.list_runs(
  project_name="langsmith-academy", 
  filter=raw_query,
  start_time=datetime.now() - timedelta(days=1),
)
for run in runs:
    print(run)
# Out:
# id=UUID('20ebf224-d475-4ff7-a32c-d011dd40f14e') name='call_openai' start_time=datetime.datetime(2025, 12, 15, 16, 42, 47, 407151) run_type='llm' end_time=datetime.datetime(2025, 12, 15, 16, 42, 50, 190700) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_model_name': 'gpt-4o-mini', 'ls_provider': 'openai', 'ls_run_depth': 2, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'messages': [{'content': "You are an assistant for question-answering tasks. \nUse the following pieces of retrieved context to answer the latest question in the conversation. \nIf you don't know the answer, just say that you don't know. \nUse three sentences maximum and keep the answer concise.\n\nWhenever possible provide a python code example to help the user get started.", 'role': 'system'}, {'content': "Context: The LANGSMITH_TRACING environment variable must be set to 'true' in order for traces to be logged to LangSmith, even when using @traceable or traceable. This allows you to toggle tracing on and off without changing your code.Additionally, you will need to set the LANGSMITH_API_KEY environment variable to your API key (see Setup for more information).By default, the traces will be logged to a project named default. To log traces to a different project, see this section.\nThe @traceable decorator is a simple way to log traces from the LangSmith Python SDK. Simply decorate any function with @traceable.\nNote that when wrapping a sync function with traceable, (e.g. formatPrompt in the example below), you should use the await keyword when calling it to\nensure the trace is logged correctly.\nPythonTypeScriptCopyfrom langsmith import traceable\nfrom openai import Client\n\nCustom instrumentation - Docs by LangChainSkip to main content🚀 Share how you're building agents for a chance to win LangChain swag!Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationManual instrumentationCustom instrumentationGet startedObservabilityEvaluationPrompt engineeringDeploymentAgent BuilderPlatform setupReferenceOverviewQuickstartConceptsTrace a RAG applicationTracing setupIntegrationsManual instrumentationCustom instrumentationTrace with APILog LLM callsLog retriever tracesMetadata parametersUpload files with tracesThreadsConfiguration & troubleshootingProject & environment settingsCost trackingAdvanced tracing techniquesData & privacyTroubleshooting guidesViewing & managing tracesFilter tracesQuery traces (SDK)Compare tracesShare or unshare a trace publiclyView server logs for a traceBulk export trace dataAutomationsSet up automation rulesConfigure webhook notifications for rulesFeedback & evaluationLog user feedback using the SDKSet up online evaluatorsMonitoring & alertingMonitor projects with dashboardsAlertsConfigure webhook notifications for alertsInsightsData type referenceRun (span) data formatFeedback data formatTrace query syntaxOn this pageUse @traceable / traceableUse the trace context manager (Python only)Use the RunTree APIExample usageEnsure all traces are submitted before exitingUsing the LangSmith SDKUsing LangChainTracing setupManual instrumentationCustom instrumentationCopy pageCopy pageIf you’ve decided you no longer want to trace your runs, you can remove the LANGSMITH_TRACING environment variable. Note that this does not affect the RunTree objects or API users, as these are meant to be low-level and not affected by the tracing toggle.\nThere are several ways to log traces to LangSmith.\nIf you are using LangChain (either Python or JS/TS), you can skip this section an ...
# id=UUID('9949a973-0bc2-45df-a86c-ec2eecdae22e') name='call_openai' start_time=datetime.datetime(2025, 12, 15, 16, 24, 12, 584640) run_type='llm' end_time=datetime.datetime(2025, 12, 15, 16, 24, 14, 693698) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_model_name': 'gpt-4o-mini', 'ls_provider': 'openai', 'ls_run_depth': 2, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'messages': [{'content': "You are an assistant for question-answering tasks. \nUse the following pieces of retrieved context to answer the latest question in the conversation. \nIf you don't know the answer, just say that you don't know. \nUse three sentences maximum and keep the answer concise.\n", 'role': 'system'}, {'content': "Context: The LANGSMITH_TRACING environment variable must be set to 'true' in order for traces to be logged to LangSmith, even when using @traceable or traceable. This allows you to toggle tracing on and off without changing your code.Additionally, you will need to set the LANGSMITH_API_KEY environment variable to your API key (see Setup for more information).By default, the traces will be logged to a project named default. To log traces to a different project, see this section.\nThe @traceable decorator is a simple way to log traces from the LangSmith Python SDK. Simply decorate any function with @traceable.\nNote that when wrapping a sync function with traceable, (e.g. formatPrompt in the example below), you should use the await keyword when calling it to\nensure the trace is logged correctly.\nPythonTypeScriptCopyfrom langsmith import traceable\nfrom openai import Client\n\nCustom instrumentation - Docs by LangChainSkip to main content🚀 Share how you're building agents for a chance to win LangChain swag!Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationManual instrumentationCustom instrumentationGet startedObservabilityEvaluationPrompt engineeringDeploymentAgent BuilderPlatform setupReferenceOverviewQuickstartConceptsTrace a RAG applicationTracing setupIntegrationsManual instrumentationCustom instrumentationTrace with APILog LLM callsLog retriever tracesMetadata parametersUpload files with tracesThreadsConfiguration & troubleshootingProject & environment settingsCost trackingAdvanced tracing techniquesData & privacyTroubleshooting guidesViewing & managing tracesFilter tracesQuery traces (SDK)Compare tracesShare or unshare a trace publiclyView server logs for a traceBulk export trace dataAutomationsSet up automation rulesConfigure webhook notifications for rulesFeedback & evaluationLog user feedback using the SDKSet up online evaluatorsMonitoring & alertingMonitor projects with dashboardsAlertsConfigure webhook notifications for alertsInsightsData type referenceRun (span) data formatFeedback data formatTrace query syntaxOn this pageUse @traceable / traceableUse the trace context manager (Python only)Use the RunTree APIExample usageEnsure all traces are submitted before exitingUsing the LangSmith SDKUsing LangChainTracing setupManual instrumentationCustom instrumentationCopy pageCopy pageIf you’ve decided you no longer want to trace your runs, you can remove the LANGSMITH_TRACING environment variable. Note that this does not affect the RunTree objects or API users, as these are meant to be low-level and not affected by the tracing toggle.\nThere are several ways to log traces to LangSmith.\nIf you are using LangChain (either Python or JS/TS), you can skip this section and go directly to the LangChain-specific instructions.\n\u200bUse @traceable / t ...

# %% [markdown]
# You can also pass in trace or tree filters too!

# %%
runs = client.list_runs(
  project_name="langsmith-academy", 
  filter="""eq(is_root, true)""",
  # trace_filter=""
  # tree_filter=""
)
for run in runs:
    print(run)
# Out:
# id=UUID('eae847aa-8a31-4834-9f4e-9586d12ea3fc') name='foo' start_time=datetime.datetime(2025, 12, 15, 17, 36, 40, 916714) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 17, 36, 40, 917294) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={} outputs={'output': 'This is a sample Run!'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats={'user_presigned_feedback': {'n': 1, 'avg': 1.0, 'stdev': 0.0, 'errors': 0, 'show_feedback_arrow': False, 'comments': [''], 'sources': ['{"type":"api","metadata":null}'], 'session_min_score': 1.0, 'session_max_score': 1.0, 'values': {}, 'contains_thread_feedback': False}} app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/eae847aa-8a31-4834-9f4e-9586d12ea3fc?trace_id=eae847aa-8a31-4834-9f4e-9586d12ea3fc&start_time=2025-12-15T17:36:40.916714' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('eae847aa-8a31-4834-9f4e-9586d12ea3fc') dotted_order='20251215T173640916714Zeae847aa-8a31-4834-9f4e-9586d12ea3fc' in_dataset=False
# id=UUID('59d00d46-459d-4594-8f2f-aa926675eb55') name='foo' start_time=datetime.datetime(2025, 12, 15, 17, 32, 22, 524826) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 17, 32, 22, 541145) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={} outputs={'output': 'This is a sample Run!'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats={'user_feedback': {'n': 1, 'avg': 1.0, 'stdev': 0.0, 'errors': 0, 'show_feedback_arrow': False, 'comments': [''], 'sources': ['{"type":"api","metadata":{},"user_id":"8b2fe9c5-1a54-444f-b8dd-1c76595e1494","ls_user_id":"8156bfed-fabb-414f-934f-c87fbbb2eb60"}'], 'session_min_score': 1.0, 'session_max_score': 1.0, 'values': {}, 'contains_thread_feedback': False}} app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/59d00d46-459d-4594-8f2f-aa926675eb55?trace_id=59d00d46-459d-4594-8f2f-aa926675eb55&start_time=2025-12-15T17:32:22.524826' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('59d00d46-459d-4594-8f2f-aa926675eb55') dotted_order='20251215T173222524826Z59d00d46-459d-4594-8f2f-aa926675eb55' in_dataset=False
# id=UUID('0ddfad92-8553-495a-9148-cfcdde4a4ad2') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 15, 16, 42, 46, 171194) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 16, 42, 50, 191994) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I set up tracing to LangSmith with @traceable?'} outputs={'output': "To set up tracing to LangSmith using the @traceable decorator, first, ensure you have your environment variables set: `LANGSMITH_TRACING` to `'true'` and `LANGSMITH_API_KEY` to your API key. Then, you can simply decorate your function with @traceable as shown below:\n\n```python\nfrom langsmith import traceable\n\n@traceable\ndef my_function():\n    # function logic here\n    pass\n```\n\nMake sure to call this function with the await keyword if it is asynchronous."} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats={'correctness': {'n': 1, 'avg': 1.0, 'stdev': 0.0, 'errors': 0, 'show_feedback_arrow': False, 'comments': [''], 'sources': ['{"type":"app","metadata":null,"user_id":"8b2fe9c5-1a54-444f-b8dd-1c76595e1494","ls_user_id":"8156bfed-fabb-414f-934f-c87fbbb2eb60","user_name":null}'], 'session_min_score': 1.0, 'session_max_score': 1.0, 'values': {}, 'contains_thread_feedback': False}, 'is_concise': {'n': 1, 'avg': 8.0, 'stdev': 0.0, 'errors': 0, 'show_feedback_arrow': False, 'comments': [''], 'sources': ['{"type":"app","metadata":null,"user_id":"8b2fe9c5-1a54-444f-b8dd-1c76595e1494","ls_user_id":"8156bfed-fabb-414f-934f-c87fbbb2eb60"}'], 'session_min_score': 8.0, 'session_max_score': 8.0, 'values': {}, 'contains_thread_feedback': False}} app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/0ddfad92-8553-495a-9148-cfcdde4a4ad2?trace_id=0ddfad92-8553-495a-9148-cfcdde4a4ad2&start_time=2025-12-15T16:42:46.171194' manifest_id=None status='success' prompt_tokens=1490 completion_tokens=109 total_tokens=1599 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=Decimal('0.0002889') prompt_cost=Decimal('0.0002235') completion_cost=Decimal('0.0000654') prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('0ddfad92-8553-495a-9148-cfcdde4a4ad2') dotted_order='20251215T164246171194Z0ddfad92-8553-495a-9148-cfcdde4a4ad2' in_dataset=False
# id=UUID('8417b078-4f4a-4c83-a0c8-3958385657a1') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 15, 16, 24, 11, 411415) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 16, 24, 14, 694744) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I set up tracing to LangSmith with @traceable?'} outputs={'output': "To set up tracing to LangSmith with the @traceable decorator, first ensure that the LANGSMITH_TRACING environment variable is set to 'true'. Then, decorate any function you want to trace with @traceable and make sure to call it using the await keyword for proper logging. Lastly, don't forget to set the LANGSMITH_API_KEY environment variable with your API key."} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/8417b078-4f4a-4c83-a0c8-3958385657a1?trace_id=8417b078-4f4a-4c83-a0c8-3958385657a1&start_time=2025-12-15T16:24:11.411415' manifest_id=None status='success' prompt_tokens=1477 completion_tokens=77 total_tokens=1554 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=Decimal('0.00026775') prompt_cost=Decimal('0.00022155') completion_cost=Decimal('0.0000462') prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('8417b078-4f4a-4c83-a0c8-3958385657a1') dotted_order='20251215T162411411415Z8417b078-4f4a-4c83-a0c8-3958385657a1' in_dataset=False
# id=UUID('6852bdf9-3221-4e19-a63c-92480610c206') name='StructuredPrompt' start_time=datetime.datetime(2025, 12, 15, 16, 14, 49, 74529) run_type='prompt' end_time=datetime.datetime(2025, 12, 15, 16, 14, 49, 75053) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'lc_hub_commit_hash': '81b406e666b8917ce2ae48830ed1f6ef53b46f696c8896f38c556df8b04dcce4', 'lc_hub_owner': '-', 'lc_hub_repo': 'pirate-friend', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langchain-core', 'library_version': '1.0.1', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'name': 'start', 'time': '2025-12-15T16:14:49.074529+00:00'}, {'name': 'end', 'time': '2025-12-15T16:14:49.075053+00:00'}] inputs={'language': 'English', 'question': 'What is the world like?'} outputs={'output': {'messages': [{'additional_kwargs': {}, 'content': 'You are a pirate from the future, year 2500, you only speak English', 'response_metadata': {}, 'type': 'system'}, {'additional_kwargs': {}, 'content': 'What is the world like?', 'response_metadata': {}, 'type': 'human'}]}} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/6852bdf9-3221-4e19-a63c-92480610c206?trace_id=6852bdf9-3221-4e19-a63c-92480610c206&start_time=2025-12-15T16:14:49.074529' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('6852bdf9-3221-4e19-a63c-92480610c206') dotted_order='20251215T161449074529Z6852bdf9-3221-4e19-a63c-92480610c206' in_dataset=False
# id=UUID('2f27c895-da22-4fb0-91f8-1ed04181280b') name='RunnableSequence' start_time=datetime.datetime(2025, 12, 15, 16, 10, 16, 720872) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 16, 10, 18, 818836) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langchain-core', 'library_version': '1.0.1', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'name': 'start', 'time': '2025-12-15T16:10:16.720872+00:00'}, {'name': 'end', 'time': '2025-12-15T16:10:18.818836+00:00'}] inputs={'language': 'Spanish', 'question': 'Are you a captain yet?'} outputs={'answer': '¡No, aún no soy capitán! Pero tengo el espíritu aventurero de un pirata y la ambición de llegar a ser capitán algún día. Navegar los mares y buscar tesoros es mi destino.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/2f27c895-da22-4fb0-91f8-1ed04181280b?trace_id=2f27c895-da22-4fb0-91f8-1ed04181280b&start_time=2025-12-15T16:10:16.720872' manifest_id=None status='success' prompt_tokens=79 completion_tokens=49 total_tokens=128 prompt_token_details={'audio': 0, 'cache_read': 0} completion_token_details={'audio': 0, 'reasoning': 0} first_token_time=None total_cost=Decimal('0.00004125') prompt_cost=Decimal('0.00001185') completion_cost=Decimal('0.0000294') prompt_cost_details={'audio': Decimal('0.0'), 'cache_read': Decimal('0.0')} completion_cost_details={'audio': Decimal('0.0'), 'reasoning': Decimal('0.0')} parent_run_ids=[] trace_id=UUID('2f27c895-da22-4fb0-91f8-1ed04181280b') dotted_order='20251215T161016720872Z2f27c895-da22-4fb0-91f8-1ed04181280b' in_dataset=False
# id=UUID('87c5ba43-5525-4850-b693-029759a44d83') name='StructuredPrompt' start_time=datetime.datetime(2025, 12, 15, 16, 2, 58, 126648) run_type='prompt' end_time=datetime.datetime(2025, 12, 15, 16, 2, 58, 128836) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'lc_hub_commit_hash': '81e31d62d5ab8178a5f10f786a1414698f7153fd65972fbd346a8a9ffdc7ce08', 'lc_hub_owner': '-', 'lc_hub_repo': 'pirate-friend', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langchain-core', 'library_version': '1.0.1', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'name': 'start', 'time': '2025-12-15T16:02:58.126648+00:00'}, {'name': 'end', 'time': '2025-12-15T16:02:58.128836+00:00'}] inputs={'language': 'Spanish', 'question': 'Are you a captain yet?'} outputs={'output': {'messages': [{'additional_kwargs': {}, 'content': 'You are a pirate from the 1600s, you only speak Spanish', 'response_metadata': {}, 'type': 'system'}, {'additional_kwargs': {}, 'content': 'Are you a captain yet?', 'response_metadata': {}, 'type': 'human'}]}} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/87c5ba43-5525-4850-b693-029759a44d83?trace_id=87c5ba43-5525-4850-b693-029759a44d83&start_time=2025-12-15T16:02:58.126648' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('87c5ba43-5525-4850-b693-029759a44d83') dotted_order='20251215T160258126648Z87c5ba43-5525-4850-b693-029759a44d83' in_dataset=False
# id=UUID('26049859-526e-4415-936e-27a6f3117c64') name='RunnableSequence' start_time=datetime.datetime(2025, 12, 15, 15, 51, 38, 306784) run_type='chain' end_time=datetime.datetime(2025, 12, 15, 15, 51, 39, 885438) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_run_depth': 0, 'revision_id': 'd19ec0f-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langchain-core', 'library_version': '1.0.1', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'name': 'start', 'time': '2025-12-15T15:51:38.306784+00:00'}, {'name': 'end', 'time': '2025-12-15T15:51:39.885438+00:00'}] inputs={'language': 'Spanish', 'question': 'Are you a captain yet?'} outputs={'answer': 'No soy capitán aún, pero navego los mares como un valiente corsario en busca de tesoros y aventuras.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/26049859-526e-4415-936e-27a6f3117c64?trace_id=26049859-526e-4415-936e-27a6f3117c64&start_time=2025-12-15T15:51:38.306784' manifest_id=None status='success' prompt_tokens=79 completion_tokens=29 total_tokens=108 prompt_token_details={'audio': 0, 'cache_read': 0} completion_token_details={'audio': 0, 'reasoning': 0} first_token_time=None total_cost=Decimal('0.00002925') prompt_cost=Decimal('0.00001185') completion_cost=Decimal('0.0000174') prompt_cost_details={'audio': Decimal('0.0'), 'cache_read': Decimal('0.0')} completion_cost_details={'audio': Decimal('0.0'), 'reasoning': Decimal('0.0')} parent_run_ids=[] trace_id=UUID('26049859-526e-4415-936e-27a6f3117c64') dotted_order='20251215T155138306784Z26049859-526e-4415-936e-27a6f3117c64' in_dataset=False
# id=UUID('55c46e58-ab98-49b2-a4cb-82156afa3447') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 12, 12, 52, 56, 49789) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 12, 52, 59, 365360) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': "How do I set up tracing to LangSmith if I'm using LangChain?"} outputs={'output': 'To set up tracing with LangSmith while using LangChain, utilize the built-in integration for tracing your application. You can also refer to the video tutorial "Alternative Ways to Trace" from the Introduction to LangSmith Course for guidance. For more detailed instructions, check the tracing setup section in the documentation.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/55c46e58-ab98-49b2-a4cb-82156afa3447?trace_id=55c46e58-ab98-49b2-a4cb-82156afa3447&start_time=2025-12-12T12:52:56.049789' manifest_id=None status='success' prompt_tokens=1084 completion_tokens=60 total_tokens=1144 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=Decimal('0.0001986') prompt_cost=Decimal('0.0001626') completion_cost=Decimal('0.000036') prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('55c46e58-ab98-49b2-a4cb-82156afa3447') dotted_order='20251212T125256049789Z55c46e58-ab98-49b2-a4cb-82156afa3447' in_dataset=False
# id=UUID('674b8e81-878e-4222-abab-adaaff7b1ff6') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 12, 11, 13, 50, 58643) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 11, 13, 53, 60725) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty', 'thread_id': '4efc3127-31ba-423b-8e06-78e504be3ff8'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How can I add tags to a Trace?'} outputs={'output': 'You can attach tags to a trace in the LangSmith UI by selecting the appropriate option when viewing the trace. Tags help categorize, filter, and group runs for easier analysis. For detailed instructions, refer to the guide on attaching tags to your traces.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/674b8e81-878e-4222-abab-adaaff7b1ff6?trace_id=674b8e81-878e-4222-abab-adaaff7b1ff6&start_time=2025-12-12T11:13:50.058643' manifest_id=None status='success' prompt_tokens=1797 completion_tokens=50 total_tokens=1847 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('674b8e81-878e-4222-abab-adaaff7b1ff6') dotted_order='20251212T111350058643Z674b8e81-878e-4222-abab-adaaff7b1ff6' in_dataset=False
# id=UUID('32aef8b7-92c3-42cb-a3da-103edc039e96') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 12, 11, 13, 45, 652001) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 11, 13, 48, 972601) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty', 'thread_id': '4efc3127-31ba-423b-8e06-78e504be3ff8'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I add metadata to a Trace?'} outputs={'output': 'You can add metadata to a trace by providing it in the `RunnableConfig` when configuring your runnable. This metadata can be a dictionary of key-value pairs that store additional information about the trace, such as the environment or user details. Additionally, you can attach metadata at runtime using invocation parameters.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/32aef8b7-92c3-42cb-a3da-103edc039e96?trace_id=32aef8b7-92c3-42cb-a3da-103edc039e96&start_time=2025-12-12T11:13:45.652001' manifest_id=None status='success' prompt_tokens=1746 completion_tokens=59 total_tokens=1805 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('32aef8b7-92c3-42cb-a3da-103edc039e96') dotted_order='20251212T111345652001Z32aef8b7-92c3-42cb-a3da-103edc039e96' in_dataset=False
# id=UUID('41827556-9d8e-4022-8c5f-e6d58e83abfa') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 12, 2, 26, 21, 118116) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 2, 26, 24, 725788) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I trace with tracing context?'} outputs={'output': 'To trace with tracing context in LangSmith, you can use the `with tracing_context` context manager, which allows you to enable or disable tracing programmatically without relying on environment variables. This method provides finer-grained control over your tracing configuration. For more details, refer to the specific examples in the documentation.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/41827556-9d8e-4022-8c5f-e6d58e83abfa?trace_id=41827556-9d8e-4022-8c5f-e6d58e83abfa&start_time=2025-12-12T02:26:21.118116' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('41827556-9d8e-4022-8c5f-e6d58e83abfa') dotted_order='20251212T022621118116Z41827556-9d8e-4022-8c5f-e6d58e83abfa' in_dataset=False
# id=UUID('c76c7f36-be40-4ce3-bda8-257ff88ce469') name='LangGraph' start_time=datetime.datetime(2025, 12, 12, 2, 22, 0, 383575) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 2, 22, 4, 667935) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'foo': 'bar', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langchain-core', 'library_version': '1.0.1', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'name': 'start', 'time': '2025-12-12T02:22:00.383575+00:00'}, {'name': 'end', 'time': '2025-12-12T02:22:04.667935+00:00'}] inputs={'question': "How do I set up tracing if I'm using LangChain?"} outputs={'documents': [{'metadata': {'changefreq': 'weekly', 'id': 'e8f9ab29-c73a-4027-86f6-d96a91c2fcb1', 'loc': 'https://docs.smith.langchain.com/observability/how_to_guides/trace_with_langgraph', 'priority': '0.5', 'source': 'https://docs.smith.langchain.com/observability/how_to_guides/trace_with_langgraph'}, 'page_content': "Trace with LangGraph - Docs by LangChainSkip to main content🚀 Share how you're building agents for a chance to win LangChain swag!Docs by LangChain home pageLangSmithSearch...⌘KAsk AIGitHubTry LangSmithTry LangSmithSearch...NavigationIntegrationsTrace with LangGraphGet startedObservabilityEvaluationPrompt engineeringDeploymentAgent BuilderPlatform setupReferenceOverviewQuickstartConceptsTrace a RAG applicationTracing setupIntegrationsOverviewLangChainLangGraphAnthropic (Python only)OpenAIAutoGenClaude Agent SDKCrewAIGoogle ADKInstructor (Python only)OpenAI Agents SDKOpenTelemetryPydanticAISemantic KernelVercel AI SDKLiveKitPipecatManual instrumentationThreadsConfiguration & troubleshootingProject & environment settingsCost trackingAdvanced tracing techniquesData & privacyTroubleshooting guidesViewing & managing tracesFilter tracesQuery traces (SDK)Compare tracesShare or unshare a trace publiclyView server logs for a traceBulk export trace dataAutomationsSet up automation rulesConfigure webhook notifications for rulesFeedback & evaluationLog user feedback using the SDKSet up online evaluatorsMonitoring & alertingMonitor projects with dashboardsAlertsConfigure webhook notifications for alertsInsightsData type referenceRun (span) data formatFeedback data formatTrace query syntaxOn this pageWith LangChain1. Installation2. Configure your environment3. Log a traceWithout LangChain1. Installation2. Configure your environment3. Log a traceTracing setupIntegrationsTrace with LangGraphCopy pageCopy pageLangSmith smoothly integrates with LangGraph (Python and JS) to help you trace agents, whether you’re using LangChain modules or other SDKs.\n\u200bWith LangChain\nIf you are using LangChain modules within LangGraph, you only need to set a few environment variables to enable tracing.\nThis guide will walk through a basic example. For more detailed information on configuration, see the Trace With LangChain guide.\n\u200b1. Installation\nInstall the LangGraph library and the OpenAI integration for Python and JS (we use the OpenAI integration for the code snippets below).\nFor a full list of packages available, see the LangChain Python docs and LangChain JS docs.", 'type': 'Document'}, {'metadata': {'changefreq': 'weekly', 'id': 'a4df6de3-6036-44bc-a60e-58009927f5f7', 'loc': 'https://docs.smith.langchain.com/observability/how_to_guides/trace_with_langchain', 'priority': '0.5', 'source': 'https://docs.smith.langchain.com/observability/how_to_guides/trace_with_langchain'}, 'page_content': "Trace with LangChain (Python and JS/TS) - Docs by LangChainSkip to main content🚀 Share how you're building agents for a chance to win LangChain swag!Docs by LangChain home pageLangSmithSearch ...
# id=UUID('cca894fd-ada8-4fcb-93ab-b162cab0fd8e') name='ask_about_the_weather' start_time=datetime.datetime(2025, 12, 12, 0, 44, 14, 982223) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 0, 44, 18, 21678) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'inputs': [{'content': 'You are a helpful assistant.', 'role': 'system'}, {'content': 'What is the weather today in New York City?', 'role': 'user'}, {'annotations': [], 'role': 'assistant', 'tool_calls': [{'function': {'arguments': '{"location":"New York City, NY","unit":"Fahrenheit"}', 'name': 'get_current_temperature'}, 'id': 'call_guE9aUtq0ExKxGhu6AHthOZn', 'type': 'function'}]}, {'content': '{"location": "New York City, NY", "unit": "Fahrenheit", "temperature": 65}', 'role': 'tool', 'tool_call_id': 'call_guE9aUtq0ExKxGhu6AHthOZn'}], 'tools': [{'function': {'description': 'Get the current temperature for a specific location', 'name': 'get_current_temperature', 'parameters': {'properties': {'location': {'description': 'The city and state, e.g., San Francisco, CA', 'type': 'string'}, 'unit': {'description': "The temperature unit to use. Infer this from the user's location.", 'enum': ['Celsius', 'Fahrenheit'], 'type': 'string'}}, 'required': ['location', 'unit'], 'type': 'object'}}, 'type': 'function'}]} outputs={'choices': [{'finish_reason': 'stop', 'index': 0, 'message': {'annotations': [], 'content': 'The current temperature in New York City is 65°F. If you need more detailed weather information, feel free to ask!', 'role': 'assistant'}}], 'created': 1765500257, 'id': 'chatcmpl-CllYXRxfcVG4yFxkA8uu2un4fdK0b', 'model': 'gpt-4o-mini-2024-07-18', 'object': 'chat.completion', 'service_tier': 'default', 'system_fingerprint': 'fp_aa07c96156', 'usage': {'completion_tokens': 25, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 83, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 108}} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/cca894fd-ada8-4fcb-93ab-b162cab0fd8e?trace_id=cca894fd-ada8-4fcb-93ab-b162cab0fd8e&start_time=2025-12-12T00:44:14.982223' manifest_id=None status='success' prompt_tokens=184 completion_tokens=49 total_tokens=233 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('cca894fd-ada8-4fcb-93ab-b162cab0fd8e') dotted_order='20251212T004414982223Zcca894fd-ada8-4fcb-93ab-b162cab0fd8e' in_dataset=False
# id=UUID('90174fae-2f12-4aad-a25a-fd7ee056ebf4') name='my_streaming_chat_model' start_time=datetime.datetime(2025, 12, 12, 0, 18, 55, 174750) run_type='llm' end_time=datetime.datetime(2025, 12, 12, 0, 18, 55, 175622) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_model_name': 'my_model', 'ls_provider': 'my_provider', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[{'kwargs': {'token': {'choices': [{'message': {'content': 'Hello, polly the parrot', 'role': 'assistant'}}]}}, 'name': 'new_token', 'time': '2025-12-12T00:18:55.175599+00:00'}] inputs={'messages': [{'content': 'You are a helpful assistant. Please greet the user.', 'role': 'system'}, {'content': 'polly the parrot', 'role': 'user'}]} outputs={'choices': [{'message': {'content': 'Hello, polly the parrot', 'role': 'assistant'}}]} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/90174fae-2f12-4aad-a25a-fd7ee056ebf4?trace_id=90174fae-2f12-4aad-a25a-fd7ee056ebf4&start_time=2025-12-12T00:18:55.174750' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details={} completion_token_details={} first_token_time=datetime.datetime(2025, 12, 12, 0, 18, 55, 175599) total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('90174fae-2f12-4aad-a25a-fd7ee056ebf4') dotted_order='20251212T001855174750Z90174fae-2f12-4aad-a25a-fd7ee056ebf4' in_dataset=False
# id=UUID('01714a04-606d-42d1-b167-8ab9fdab655e') name='chat_model' start_time=datetime.datetime(2025, 12, 12, 0, 18, 52, 677569) run_type='chain' end_time=datetime.datetime(2025, 12, 12, 0, 18, 52, 693600) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'messages': [{'content': 'You are a helpful assistant.', 'role': 'system'}, {'content': "I'd like to book a table for two.", 'role': 'user'}]} outputs={'choices': [{'message': {'content': 'Sure, what time would you like to book the table for?', 'role': 'assistant'}}]} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/01714a04-606d-42d1-b167-8ab9fdab655e?trace_id=01714a04-606d-42d1-b167-8ab9fdab655e&start_time=2025-12-12T00:18:52.677569' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('01714a04-606d-42d1-b167-8ab9fdab655e') dotted_order='20251212T001852677569Z01714a04-606d-42d1-b167-8ab9fdab655e' in_dataset=False
# id=UUID('78c64768-6525-4e75-88e6-ba9a9c795f31') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 23, 33, 19, 135753) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 23, 33, 22, 901464) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty', 'runtime_metadata': 'foo'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I add metadata at runtime?'} outputs={'output': 'You can add metadata at runtime by passing it as part of the invocation parameters when you call the `invoke` method. For example, you can include a dictionary with your metadata in the second argument of the `invoke` method, like this: `chain.invoke({"input": "your input"}, {"metadata": {"your-key": "your-value"}})`. This metadata will be associated with the specific invocation of the runnable.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/78c64768-6525-4e75-88e6-ba9a9c795f31?trace_id=78c64768-6525-4e75-88e6-ba9a9c795f31&start_time=2025-12-11T23:33:19.135753' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('78c64768-6525-4e75-88e6-ba9a9c795f31') dotted_order='20251211T233319135753Z78c64768-6525-4e75-88e6-ba9a9c795f31' in_dataset=False
# id=UUID('3e035400-f6c1-480a-989b-61911e698e2a') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 23, 29, 25, 298985) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 23, 29, 29, 489133) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'How do I add Metadata to a Run with @traceable?'} outputs={'output': 'To add metadata to a run with `@traceable`, you can include the metadata in the `experimental_telemetry` object when invoking the function. For example, you can pass a `metadata` key with your desired key-value pairs. This metadata will then be associated with the run and visible in your LangSmith dashboard.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/3e035400-f6c1-480a-989b-61911e698e2a?trace_id=3e035400-f6c1-480a-989b-61911e698e2a&start_time=2025-12-11T23:29:25.298985' manifest_id=None status='success' prompt_tokens=0 completion_tokens=0 total_tokens=0 prompt_token_details=None completion_token_details=None first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details=None completion_cost_details=None parent_run_ids=[] trace_id=UUID('3e035400-f6c1-480a-989b-61911e698e2a') dotted_order='20251211T232925298985Z3e035400-f6c1-480a-989b-61911e698e2a' in_dataset=False
# id=UUID('a5bb1a7a-b243-44d4-8336-032deb79a4ab') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 16, 17, 22, 276366) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 16, 17, 26, 489813) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '12de301-dirty', 'website': 'www.google.com'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'What is LangSmith used for?'} outputs={'output': 'LangSmith is used for developing, debugging, and deploying LLM applications. It provides tools for tracing requests, evaluating outputs, testing prompts, and managing deployments in one place. Additionally, it is framework agnostic, allowing use with or without LangChain’s libraries.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/a5bb1a7a-b243-44d4-8336-032deb79a4ab?trace_id=a5bb1a7a-b243-44d4-8336-032deb79a4ab&start_time=2025-12-11T16:17:22.276366' manifest_id=None status='success' prompt_tokens=1376 completion_tokens=53 total_tokens=1429 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('a5bb1a7a-b243-44d4-8336-032deb79a4ab') dotted_order='20251211T161722276366Za5bb1a7a-b243-44d4-8336-032deb79a4ab' in_dataset=False
# id=UUID('b0a41ea7-2699-4996-9c3d-0dc8be3a7345') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 1, 57, 55, 845695) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 1, 57, 58, 454394) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '11713fe-dirty', 'website': 'www.google.com'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'What is LangSmith used for?'} outputs={'output': 'LangSmith is used for developing, debugging, and deploying LLM applications. It provides tools for tracing requests, evaluating outputs, testing prompts, and managing deployments in one place. Additionally, it is framework agnostic, allowing use with or without LangChain’s libraries.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/b0a41ea7-2699-4996-9c3d-0dc8be3a7345?trace_id=b0a41ea7-2699-4996-9c3d-0dc8be3a7345&start_time=2025-12-11T01:57:55.845695' manifest_id=None status='success' prompt_tokens=1376 completion_tokens=53 total_tokens=1429 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('b0a41ea7-2699-4996-9c3d-0dc8be3a7345') dotted_order='20251211T015755845695Zb0a41ea7-2699-4996-9c3d-0dc8be3a7345' in_dataset=False
# id=UUID('f6e6c7de-57bc-4207-99a8-1b7bd491ffe2') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 1, 40, 49, 28912) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 1, 40, 51, 742718) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '11713fe-dirty', 'website': 'www.google.com'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'What is LangSmith used for?'} outputs={'output': 'LangSmith is used for developing, debugging, and deploying LLM applications. It provides tools for tracing requests, evaluating outputs, testing prompts, and managing deployments in one place. Additionally, it is framework agnostic, allowing use with or without LangChain’s libraries.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/f6e6c7de-57bc-4207-99a8-1b7bd491ffe2?trace_id=f6e6c7de-57bc-4207-99a8-1b7bd491ffe2&start_time=2025-12-11T01:40:49.028912' manifest_id=None status='success' prompt_tokens=1376 completion_tokens=53 total_tokens=1429 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('f6e6c7de-57bc-4207-99a8-1b7bd491ffe2') dotted_order='20251211T014049028912Zf6e6c7de-57bc-4207-99a8-1b7bd491ffe2' in_dataset=False
# id=UUID('acfb8854-c453-4893-9bf2-4c2310c78b4a') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 1, 22, 27, 977819) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 1, 22, 30, 882112) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '0b17e63-dirty', 'website': 'www.google.com'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'What is LangSmith used for?'} outputs={'output': 'LangSmith is used for developing, debugging, and deploying LLM applications. It provides tools for tracing requests, evaluating outputs, testing prompts, and managing deployments in one place. Additionally, it is framework agnostic, allowing integration with or without LangChain’s libraries.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/acfb8854-c453-4893-9bf2-4c2310c78b4a?trace_id=acfb8854-c453-4893-9bf2-4c2310c78b4a&start_time=2025-12-11T01:22:27.977819' manifest_id=None status='success' prompt_tokens=1376 completion_tokens=53 total_tokens=1429 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('acfb8854-c453-4893-9bf2-4c2310c78b4a') dotted_order='20251211T012227977819Zacfb8854-c453-4893-9bf2-4c2310c78b4a' in_dataset=False
# id=UUID('eec3288f-1fec-453c-89ef-ecc8402a1465') name='langsmith_rag' start_time=datetime.datetime(2025, 12, 11, 1, 17, 44, 518139) run_type='chain' end_time=datetime.datetime(2025, 12, 11, 1, 17, 47, 27815) extra={'metadata': {'LANGSMITH_ENDPOINT': 'https://eu.api.smith.langchain.com', 'LANGSMITH_PROJECT': 'langsmith-academy', 'LANGSMITH_TRACING': 'true', 'LANGSMITH_TRACING_V2': 'true', 'ls_method': 'traceable', 'ls_run_depth': 0, 'revision_id': '0b17e63-dirty', 'website': 'www.google.com'}, 'runtime': {'langchain_core_version': '1.0.1', 'langchain_version': '1.0.1', 'library': 'langsmith', 'platform': 'macOS-14.6-arm64-arm-64bit', 'py_implementation': 'CPython', 'runtime': 'python', 'runtime_version': '3.12.10', 'sdk': 'langsmith-py', 'sdk_version': '0.4.38'}} error=None serialized=None events=[] inputs={'question': 'What is LangSmith used for?'} outputs={'output': 'LangSmith is used for developing, debugging, and deploying LLM applications. It provides tools for tracing requests, evaluating outputs, testing prompts, and managing deployments in one place. Additionally, it is framework agnostic, allowing use with or without LangChain’s libraries.'} reference_example_id=None parent_run_id=None tags=[] attachments={} session_id=UUID('527cc6a2-7df2-4b7c-b1dd-ba52f0be1556') child_run_ids=None child_runs=None feedback_stats=None app_path='/o/05f40a35-2d5e-4cd4-9466-b540440921d2/projects/p/527cc6a2-7df2-4b7c-b1dd-ba52f0be1556/r/eec3288f-1fec-453c-89ef-ecc8402a1465?trace_id=eec3288f-1fec-453c-89ef-ecc8402a1465&start_time=2025-12-11T01:17:44.518139' manifest_id=None status='success' prompt_tokens=1376 completion_tokens=53 total_tokens=1429 prompt_token_details={} completion_token_details={} first_token_time=None total_cost=None prompt_cost=None completion_cost=None prompt_cost_details={} completion_cost_details={} parent_run_ids=[] trace_id=UUID('eec3288f-1fec-453c-89ef-ecc8402a1465') dotted_order='20251211T011744518139Zeec3288f-1fec-453c-89ef-ecc8402a1465' in_dataset=False
